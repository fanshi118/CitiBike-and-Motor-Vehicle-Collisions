# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, datetime, statsmodels.formula.api as smf, matplotlib.dates as mdates
# %matplotlib inline
plt.style.use('ggplot')

# %%
def convertDate(d):
    dt = datetime.datetime.strptime(d, '%m/%d/%Y')
    return dt

df = pd.read_csv('data/NYPD_Motor_Vehicle_Collisions.csv', converters={'DATE': convertDate})

# %%
c_inj_agg = df.groupby('DATE').sum()['NUMBER OF CYCLIST INJURED']

# %%
df_ = df[(df['NUMBER OF CYCLIST INJURED']>0)|(df['NUMBER OF CYCLIST KILLED']>0)]
print len(df),len(df_)
# Out:
# 716227 14340

# %%
df_.head()
# Out:
#           DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 17  2015-12-12  15:20     QUEENS     11435  40.693590 -73.800189
# 44  2015-12-12  16:29   BROOKLYN     11226  40.644852 -73.960016
# 87  2015-12-12  17:37  MANHATTAN     10002  40.715855 -73.994953
# 91  2015-12-12  17:40   BROOKLYN     11221  40.686649 -73.920739
# 128 2015-12-12  18:29  MANHATTAN     10014  40.732854 -74.007523
#
#                       LOCATION      ON STREET NAME  CROSS STREET NAME  \
# 17   (40.6935895, -73.8001891)     LAKEWOOD AVENUE  SUTPHIN BOULEVARD
# 44   (40.6448523, -73.9600159)        OCEAN AVENUE      BEVERLEY ROAD
# 87   (40.7158555, -73.9949534)     CHRYSTIE STREET       CANAL STREET
# 91   (40.6866487, -73.9207388)    JEFFERSON AVENUE      HOWARD AVENUE
# 128  (40.7328536, -74.0075232)  CHRISTOPHER STREET   GREENWICH STREET
#
#     OFF STREET NAME         ...          CONTRIBUTING FACTOR VEHICLE 2  \
# 17              NaN         ...                            Unspecified
# ...

# %%
df_.to_csv('data/Bicycle_Collisions.csv')

# %%
df__ = df[df['NUMBER OF CYCLIST KILLED']>0]
df__.to_csv('data_/Bicycle_Deaths.csv')

# %%
d = pd.Timestamp(datetime.datetime(2013, 7, 1))

# %%
d1 = df_[df_['DATE']<d]
d2 = df_[df_['DATE']>=d]

# %%
print len(d1),len(d2)
d1
# Out:
# 3914 10426
#              DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 516048 2013-06-30   0:10   BROOKLYN     11221  40.691624 -73.942661
# 516077 2013-06-30  10:57   BROOKLYN     11205  40.692778 -73.957679
# 516100 2013-06-30  12:00     QUEENS     11368  40.742845 -73.851210
# 516130 2013-06-30  13:09     QUEENS     11354  40.776627 -73.839054
# 516187 2013-06-30  15:20     QUEENS     11372  40.749940 -73.882450
# 516262 2013-06-30  17:50     QUEENS     11366  40.735604 -73.775154
# 516331 2013-06-30   1:30        NaN       NaN        NaN        NaN
# 516354 2013-06-30  21:35      BRONX     10472  40.830078 -73.853762
# 516362 2013-06-30  22:00     QUEENS     11105  40.779747 -73.915819
# 516363 2013-06-30  22:00     QUEENS     11354  40.772790 -73.837124
# 516391 2013-06-30   2:20      BRONX     10457  40.838875 -73.902647
# 516406 2013-06-30   3:30      BRONX     10452  40.843823 -73.916554
# 516442 2013-06-30   6:45   BROOKLYN     11215  40.675437 -73.977958
# ...

# %%
d1.to_csv('data/b4ct_collisions.csv')
d2.to_csv('data/afct_collisions.csv')

# %%
inj_b4 = d1.groupby('ZIP CODE').sum()['NUMBER OF CYCLIST INJURED']
inj_af = d2.groupby('ZIP CODE').sum()['NUMBER OF CYCLIST INJURED']

# %%
inj_b4.values
# Out:
# array([ 1, 46, 80, 75,  6,  6,  1, 15, 49, 51, 48, 28, 29, 17, 55, 27, 28,
#        49,  1, 28, 39, 31, 18, 23, 23, 32, 12, 27, 12, 18, 10, 16, 13, 14,
#        32,  5, 12,  6, 10, 12,  1, 11,  1, 23,  2,  2,  7,  4,  3,  5,  4,
#         6,  2,  1,  5,  2,  3, 11, 15, 11,  8,  9, 14, 15, 23, 13, 19, 13,
#        13,  6,  2,  8, 11, 14, 20, 10,  1,  2, 18, 10, 10,  3,  3, 39, 23,
#        35, 18, 14, 20, 44, 53, 39, 63, 91, 69, 32, 24, 29, 71, 47, 43, 25,
#        49, 56, 56, 42, 37, 47, 43, 40, 36, 15, 50, 54, 14, 30, 42, 13, 34,
#        31, 22, 27, 21, 24, 57,  1, 30, 15, 15,  2,  5,  6,  4,  1,  6,  6,
#         3,  3,  7, 68, 14,  9, 75, 34,  9, 17, 50, 11,  9, 28,  4, 16,  9,
#         1,  7,  9,  6, 10, 16, 12, 15,  5,  4,  4,  2,  3,  5,  8,  8, 12,
#         4,  5, 13,  2,  6,  3])

# %%
df_b4 = pd.DataFrame(columns=['ZipCode','NumberofIncidents'])
df_b4['ZipCode'] = inj_b4.index
df_b4['NumberofIncidents'] = inj_b4.values
df_b4
# Out:
#      ZipCode  NumberofIncidents
# 0      10000                  1
# 1      10001                 46
# 2      10002                 80
# 3      10003                 75
# 4      10004                  6
# 5      10005                  6
# 6      10006                  1
# 7      10007                 15
# 8      10009                 49
# 9      10010                 51
# 10     10011                 48
# 11     10012                 28
# 12     10013                 29
# 13     10014                 17
# 14     10016                 55
# 15     10017                 27
# 16     10018                 28
# 17     10019                 49
# 18     10020                  1
# 19     10021                 28
# 20     10022                 39
# 21     10023                 31
# 22     10024                 18
# 23     10025                 23
# 24     10026                 23
# 25     10027                 32
# 26     10028                 12
# 27     10029                 27
# ...

# %%
df_b4 = df_b4.sort(['NumberofIncidents'],ascending=False)
df_b4[:20]
# Out:
#      ZipCode  NumberofIncidents
# 93     11206                 91
# 2      10002                 80
# 3      10003                 75
# 142    11372                 75
# 98     11211                 71
# 94     11207                 69
# 139    11368                 68
# 92     11205                 63
# 124    11238                 57
# 103    11216                 56
# 104    11217                 56
# 14     10016                 55
# 113    11226                 54
# 90     11203                 53
# 9      10010                 51
# 112    11225                 50
# 146    11377                 50
# 17     10019                 49
# 8      10009                 49
# 102    11215                 49

# %%
df_b4.to_csv('data_/b4_collision_zip.csv')

# %%
df_af = pd.DataFrame(columns=['ZipCode','NumberofIncidents'])
df_af['ZipCode'] = inj_af.index
df_af['NumberofIncidents'] = inj_af.values
df_af = df_af.sort(['NumberofIncidents'],ascending=False)
df_af[:20]
# Out:
#      ZipCode  NumberofIncidents
# 96     11211                250
# 91     11206                230
# 1      10002                199
# 2      10003                168
# 137    11368                166
# 111    11226                166
# 8      10010                165
# 90     11205                163
# 92     11207                152
# 13     10016                150
# 106    11221                145
# 122    11238                145
# 100    11215                143
# 16     10019                137
# 87     11201                137
# 102    11217                135
# 101    11216                133
# 144    11377                130
# 7      10009                128
# 140    11372                128

# %%
df_af.to_csv('data_/af_collision_zip.csv')
